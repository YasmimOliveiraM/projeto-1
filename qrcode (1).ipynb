# %%
# !pip install jupyter-dash

# %%
# !pip install qrcode

# %%
import qrcode
from time import sleep
from jupyter_dash import JupyterDash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px
from dash import *

import pandas as pd
# Out:
# C:\Users\LaMAC\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   after removing the cwd from sys.path.
# C:\Users\LaMAC\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   """

# %%
'''
print('\033[1;34mSISTEMA DE PESQUISA DE PÁGINAS DA PUC-RIO\033[m')

#Solicitar o tipo de acesso (Site ou Instagram)
search = input('O que você gostaria de acessar hoje?\n'
               'Site\n'
               'Instagram\n').strip().title()

if search == 'Site':
   # print('PROCESSANDO...')
   # sleep(1)


    #Solicitar o departamento desejado
    qual = input('Qual departamento você deseja acessar? \n'
                 'CCEC\n'
                 'PUC-URGENTE\n'
                 'MEDPUC\n'
                 'CEIC\n'
                 'CCEAD\n'
                 'PUA\n'
                 'DAD\n'
                 'PVC\n'
                 'CACC\n').strip().upper()

    # Dicionário de links
    link_padrao = {
        'CCEC': 'https://www.cce.puc-rio.br/',
        'PUC-URGENTE': 'https://pucurgente.com.puc-rio.br/',
        'MEDPUC': 'https://www.med.puc-rio.br/',
        'CEIC': 'https://www.puc-rio.br/sobrepuc/admin/vrc/ceic/',
        'CCEAD': 'https://ead.puc-rio.br/loginccead/',
        'PUA':  'http://www.pastoraluniversitaria.puc-rio.br/',
        'DAD': 'https://www.dad.puc-rio.br/',
        'PVC': 'http://pvcsejamais.pastoraluniversitaria.puc-rio.br/',
        'CACC':  'https://linktr.ee/caccpucrio'
    }

    # Verificar se o departamento está no dicionário e criar os QR Codes
    if qual in link_padrao:
        link = link_padrao[qual]
        imagem_qrcode = qrcode.make(link)
        imagem_qrcode.save(f'qrcode_{qual}.png')
        print(f'QR Code gerado com sucesso para o departamento {qual}.')
    else:
        print('Departamento não encontrado.')


elif  search == 'Instagram':
   #Solicitar o departamento desejado
    qual = input('Qual departamento você deseja acessar? \n'
                 'CCEC\n'
                 'PUC-URGENTE\n'
                 'MEDPUC\n'
                 'CEIC\n'
                 'CCEAD\n'
                 'PUA\n'
                 'DAD\n'
                 'PVC\n'
                 'CACC\n').strip().upper()

        # Dicionário de links
    link_padrao = {
        'CCEC': 'https://www.instagram.com/ccepucrio',
        'PUC-URGENTE': 'https://www.instagram.com/puc.urgente/',
        'MEDPUC': 'https://www.instagram.com/medpucrio/',
        'CEIC': 'https://www.instagram.com/ceicpucrio/',
        'CCEAD': 'https://www.instagram.com/cceadpucrio/',
        'PUA':  'https://www.instagram.com/pastoraluniversitariapucrio/',
        'DAD': 'https://www.instagram.com/designpucrio/',
        'PVC': 'https://www.instagram.com/pvcpucrio/',
        'CACC': 'https://www.instagram.com/caccpucrio/'
    }

     # Verificar se o departamento está no dicionário e criar os QR Codes
    if qual in link_padrao:
        link = link_padrao[qual]
        imagem_qrcode = qrcode.make(link)
        imagem_qrcode.save(f'qrcode_{qual}.png')
        print(f'QR Code gerado com sucesso para o departamento {qual}.')
    else:
        print('Departamento não encontrado.')

'''
# Out:
# "\nprint('\x1bSISTEMA DE PESQUISA DE PÁGINAS DA PUC-RIO\x1b[m')\n\n#Solicitar o tipo de acesso (Site ou Instagram)\nsearch = input('O que você gostaria de acessar hoje?\n'\n               'Site\n'\n               'Instagram\n').strip().title()\n\nif search == 'Site':\n   # print('PROCESSANDO...')\n   # sleep(1)\n\n\n    #Solicitar o departamento desejado\n    qual = input('Qual departamento você deseja acessar? \n'\n                 'CCEC\n'\n                 'PUC-URGENTE\n'\n                 'MEDPUC\n'\n                 'CEIC\n'\n                 'CCEAD\n'\n                 'PUA\n'\n                 'DAD\n'\n                 'PVC\n'\n                 'CACC\n').strip().upper()\n\n    # Dicionário de links\n    link_padrao = {\n        'CCEC': 'https://www.cce.puc-rio.br/',\n        'PUC-URGENTE': 'https://pucurgente.com.puc-rio.br/',\n        'MEDPUC': 'https://www.med.puc-rio.br/',\n        'CEIC': 'https://www.puc-rio.br/sobrepuc/admin/vrc/ceic/',\n        'CCEAD': 'https://ead.puc
# ...

# %%
#import PIL
#imagem_qrcode = qrcode.make('http://google.com')
#type(Imagem.get_image())

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\LaMAC\\Downloads'

# %%
from PIL import Image
app = Dash(__name__,
           external_stylesheets=[
               'C:/Users/LaMAC/Desktop/assets/estilo.css',
               'https://cdn.jsdelivr.net/npm/bootstrap@5.3.2/dist/css/bootstrap.min.css'
           ],external_scripts=[
               'https://cdn.jsdelivr.net/npm/bootstrap@5.3.2/dist/js/bootstrap.bundle.min.js'
           ]
          
          )

app.layout = html.Center(id='raiz',children=[
    html.H1(children='Sistema de pesquisa de páginas da PUC-RIO'),
    html.Br(),
    html.Br(),
    html.Div(className='container',children=[
        html.Div(className='row',children=[
            html.H2(className='col-sm-12',children='Qual departamento você deseja acessar?')
        ])]),
                 
                 
        html.Div(className='container pt-5',children=[
        html.Div(className='row',children=[
            html.Div(className='col-sm-1'),
            html.Div(className='col-sm-2',children=html.Button(id='botao2',children=html.H2('CCEC'))),
            html.Div(className='col-sm-2',children=html.Button(id='botao3',children=html.H2('PUC-URGENTE'))),
            html.Div(className='col-sm-2',children=html.Button(id='botao4',children=html.H2('MEDPUC'))),
            html.Div(className='col-sm-2',children=html.Button(id='botao5',children=html.H2('CEIC'))),
            html.Div(className='col-sm-2',children=html.Button(id='botao6',children=html.H2('CCEAD'))),
            html.Div(className='col-sm-1')
            ])]),
            
            html.Div(className='container pt-5',children=[
        html.Div(className='row',children=[
            html.Div(className='col-sm-1'),
            html.Div(className='col-sm-2',children=html.Button(id='botao7',children=html.H2('PUA'))),
            html.Div(className='col-sm-2',children=html.Button(id='botao8',children=html.H2('DAD'))),
            html.Div(className='col-sm-2',children=html.Button(id='botao9',children=html.H2('PVC'))),
            html.Div(className='col-sm-2',children=html.Button(id='botao10',children=html.H2('CACC'))),
            html.Div(className='col-sm-2',children=html.Button(id='botao11',children=html.H2('DCE'))),
            html.Div(className='col-sm-1'),
        ])]),
    
        html.Div(className='container pt-5',children=[
        html.Div(className='row',children=[
            html.Div(className='col-sm-1'),
            html.Div(className='col-sm-2',children=html.Button(id='botao12',children=html.H2('DAU'))),
            html.Div(className='col-sm-2',children=html.Button(id='botao13',children=html.H2('DPF'))),
            html.Div(className='col-sm-2',children=html.Button(id='botao14',children=html.H2('NEAM'))),
            html.Div(className='col-sm-2',children=html.Button(id='botao15',children=html.H2('DI'))),
            html.Div(className='col-sm-2',children=html.Button(id='botao16',children=html.H2('DAAF'))),
            html.Div(className='col-sm-1')
        
        ])]),
    
        
        dcc.Input(id='p1',type='hidden',value='CCEC'),
     html.Br(),
     html.Br(),
     html.Br(),
     html.Div(className='container pt-5',children=[
        html.Div(className='row',children=[
            html.Div(className='col-sm-5'),
            html.H2(className='col-sm-2',children='O que você gostaria de acessar hoje?'),
            html.Div(className='col-sm-5'),
        ])]),
    
        html.Div(className='container pt-5',children=[
        html.Div(className='row',children=[
            html.Div(className="col-sm-4"),
            html.Div(className='col-sm-2',children=html.Button(id='botao0',children=html.H2('Site'))),  
            html.Div(className='col-sm-2',children=html.Button(id='botao1',children=html.H2('Instagram'))),
            html.Div(className="col-sm-4")
        ])]),
    
        dcc.Input(id='p0',type='hidden',value='Site'),
        html.Div(className='container pt-5',children=[
            html.Button(id='botao17',children=html.H2('gerar link ou qrcode'))]),
        html.P(id='saida')
    ])



@callback(
    Output('saida','children'),
    State('p0','value'),
    State('p1','value'),
    Input('botao17','n_clicks'),
    prevent_initial_call=True

)

def puc(a,b,c):
    #a=site ou instagram
    #b=dep
    #implementar gerador de QR code
    #retornar respectivo link
    #combinações=['CCEC','Site','CCEC','Instagram','PUC-URGENTE']
    ret={'Site':{
        'CCEC': 'https://www.cce.puc-rio.br/',
        'PUC-URGENTE': 'https://pucurgente.com.puc-rio.br/',
        'MEDPUC': 'https://www.med.puc-rio.br/',
        'CEIC': 'https://www.puc-rio.br/sobrepuc/admin/vrc/ceic/',
        'CCEAD': 'https://ead.puc-rio.br/loginccead/',
        'PUA': 'http://www.pastoraluniversitaria.puc-rio.br/',
        'DAD': 'https://www.dad.puc-rio.br/',
        'PVC': 'http://pvcsejamais.pastoraluniversitaria.puc-rio.br/',
        'CACC': 'https://linktr.ee/caccpucrio',
        'DCE': 'https://linktr.ee/DCEpucrio',
        'DAU': 'http://www.dau.puc-rio.br/home/',
        'DPF': 'https://www.fis.puc-rio.br/',
        'NEAM': 'https://linktr.ee/neampucr',
        'DI': 'https://instabio.cc/dipucrio',
        'DAAF':'https://linktr.ee/daafpucrio'
    },     
    'Instagram':{
        'CCEC': 'https://www.instagram.com/ccepucrio',
        'PUC-URGENTE': 'https://www.instagram.com/puc.urgente/',
        'MEDPUC': 'https://www.instagram.com/medpucrio/',
        'CEIC': 'https://www.instagram.com/ceicpucrio/',
        'CCEAD': 'https://www.instagram.com/cceadpucrio/',
        'PUA':  'https://www.instagram.com/pastoraluniversitariapucrio/',
        'DAD': 'https://www.instagram.com/designpucrio/',
        'PVC': 'https://www.instagram.com/pvcpucrio/',
        'CACC': 'https://www.instagram.com/caccpucrio/',
        'DCE': 'https://www.instagram.com/pucriodce/',
        'DAU': 'https://www.instagram.com/dau.puc_rio/',
        'DPF': 'https://www.instagram.com/fisica_puc_rio/',
        'NEAM': 'https://www.instagram.com/neampucrio/',
        'DI': 'https://www.instagram.com/dipucrio/',
        'DAAF':'https://www.instagram.com/daafpucrio/'
    }}
    #
    img = qrcode.make(ret[a][b]).get_image()
    #
    return html.Div(children=[html.Img(src=img,id='saida2'),html.Br(),html.A(href=ret[a][b],children=a+' '+b,target='top')])


@callback(
    Output('p0','value',
    allow_duplicate=True),
    Input('botao0','n_clicks'),
    State('p1','value'),
    prevent_initial_call=True

)

def puc(a,b):
    return 'Site'

@callback(
    Output('p0','value',
    allow_duplicate=True),
    Input('botao1','n_clicks'),
    State('p1','value'),
    prevent_initial_call=True

)

def puc(a,b):
    return 'Instagram'

@callback(
    Output('p1','value',
    allow_duplicate=True),
    Input('botao2','n_clicks'),
    prevent_initial_call=True

)

def puc(a):
    return 'CCEC'


@callback(
    Output('p1','value',
    allow_duplicate=True),
    Input('botao3','n_clicks'),
    prevent_initial_call=True

) 

def puc(a):
    return 'PUC-URGENTE'



@callback(
    Output('p1','value',
    allow_duplicate=True),
    Input('botao4','n_clicks'),
    prevent_initial_call=True

) 

def puc(a):
    return 'MEDPUC'


@callback(
    Output('p1','value',
    allow_duplicate=True),
    Input('botao5','n_clicks'),
    prevent_initial_call=True

) 

def puc(a):
    return 'CEIC'


@callback(
    Output('p1','value', 
    allow_duplicate=True),
    Input('botao6','n_clicks'),
    prevent_initial_call=True

) 

def puc(a):
    return 'CCEAD'


@callback(
    Output('p1','value',
    allow_duplicate=True),
    Input('botao7','n_clicks'),
    prevent_initial_call=True

) 

def puc(a):
    return 'PUA'


@callback(
    Output('p1','value',
    allow_duplicate=True),
    Input('botao8','n_clicks'),
    prevent_initial_call=True

) 

def puc(a):
    return 'DAD'



@callback(
    Output('p1','value',
    allow_duplicate=True),
    Input('botao9','n_clicks'),
    prevent_initial_call=True

) 

def puc(a):
    return 'PVC'


@callback(
    Output('p1','value',
    allow_duplicate=True),
    Input('botao10','n_clicks'),
    prevent_initial_call=True

) 

def puc(a):
    return 'CACC'


@callback(
    Output('p1','value',
    allow_duplicate=True),
    Input('botao11','n_clicks'),
    prevent_initial_call=True

) 

def puc(a):
    return 'DCE'

@callback(
    Output('p1','value',
    allow_duplicate=True),
    Input('botao12','n_clicks'),
    prevent_initial_call=True

) 

def puc(a):
    return 'DAU'

@callback(
    Output('p1','value',
    allow_duplicate=True),
    Input('botao13','n_clicks'),
    prevent_initial_call=True
) 

def puc(a):
    return 'DPF'

@callback(
    Output('p1','value',
    allow_duplicate=True),
    Input('botao14','n_clicks'),
    prevent_initial_call=True
) 

def puc(a):
    return 'NEAM'

@callback(
    Output('p1','value',
    allow_duplicate=True),
    Input('botao15','n_clicks'),
    prevent_initial_call=True
) 

def puc(a):
    return 'DI'

@callback(
    Output('p1','value',
    allow_duplicate=True),
    Input('botao16','n_clicks'),
    prevent_initial_call=True
) 

def puc(a):
    return 'DAAF'


if __name__ == '__main__':
    app.run(debug=True,port=8080)
    #http://127.0.0.1:8080
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8080/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import qrcode 

imagem_qrcode = qrcode.make('https://gaap-pucrio.com/')
imagem_qrcode.save('qrcode_.png')

# %%
imagem_qrcode
